# %% [markdown]
# <a href="https://colab.research.google.com/github/bsshewale/Online-retail-customer-segmentation/blob/main/Online_retail_customer_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Bharat Shewale

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# * In ecommerce companies like online retails, customer segmentation is necessary in order to understand customers behaviors. It leverages aqcuired customer data like the one we have in our case, transactions data in order to divide customers into groups.
# * Our goal in this Notebook is to cluster our customers to get insights in:
#
#   * Increasing revenue (Knowing customers who present most of our revenue)
#   * Increasing customer retention
#   * Discovering Trends and patterns
#   * Defining customers at risk

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **To find the answer of following question**
# * Who are our best customers?
# * Who has the potential to be converted in more profitable customers?
# * Which customers we must retain?
# * Which group of customers is most likely to respond to our current campaign?

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np

import time, warnings
import datetime as dt

#modules for predictive models
import sklearn.cluster as cluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

from sklearn.metrics import silhouette_samples, silhouette_score

#visualizations
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline
import seaborn as sns
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
retail_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Assignments/Project 5/Copy of Online Retail.xlsx")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
retail_uk = retail_df[retail_df['Country']=='United Kingdom']
#check the shape
retail_uk.shape
# Out:
# (495478, 8)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
retail_df.duplicated().sum()
# Out:
# 5268

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
retail_df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Visualizing the missing values
retail_df.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * Dataset is containing shape 495478 rows and 8 columns.
# * There are some duplicated and also na values in the dataset

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
retail_uk.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Dataset Describe
retail_uk.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  495478.000000  495478.000000  361878.000000
# mean        8.605486       4.532422   15547.871368
# std       227.588756      99.315438    1594.402590
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   14194.000000
# 50%         3.000000       2.100000   15514.000000
# 75%        10.000000       4.130000   16931.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("Number of transactions: ", retail_uk['InvoiceNo'].nunique())
print("Number of products bought: ",retail_uk['StockCode'].nunique())
print("Number of customers:", retail_uk['CustomerID'].nunique() )
print("Percentage of customers NA: ", round(retail_uk['CustomerID'].isnull().sum() * 100 / len(retail_df),2),"%" )
# Out:
# Number of transactions:  23494
# Number of products bought:  4065
# Number of customers: 3950
# Percentage of customers NA:  24.65 %

# %% [markdown]
# ## 3. **Data Wrangling, Model implementation and Data visualization**

# %% [markdown]
# ## **Feature Engineering & Data Pre-processing**

# %%
# Write your code to make your dataset analysis ready.
# remove canceled orders
retail_uk = retail_uk[retail_uk['Quantity']>0]
retail_uk.shape
# Out:
# (486286, 8)

# %% [markdown]
# ### Handling missing values

# %%
# remove rows where customerID are NA
retail_uk.dropna(subset=['CustomerID'],how='all',inplace=True)
retail_uk.shape
# Out:
# (354345, 8)

# %% [markdown]
# ### Reducing the dimensionality of dataset

# %%
# restrict the data to one full year because it's better to use a metric per Months or Years in RFM
retail_uk = retail_uk[retail_uk['InvoiceDate']>= "2010-12-09"]
retail_uk.shape
# Out:
# (342478, 8)

# %% [markdown]
# ## **Applying RFM model**
# ### RFM Analysis
# * RFM (Recency, Frequency, Monetary) analysis is a customer segmentation technique that uses past purchase behavior to divide customers into groups.
# * RFM helps divide customers into various categories or clusters to identify customers who are more likely to respond to promotions and also for future personalization services.
#
#   * RECENCY (R): Days since last purchase
#   * FREQUENCY (F): Total number of purchases
#   * MONETARY VALUE (M): Total money this customer spent.

# %% [markdown]
# ### Recency

# %%
# last date available in our dataset
retail_uk['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %% [markdown]
# The last date we have is 2011-12-09 so we will use it as reference.

# %%
now = dt.date(2011,12,9)
print(now)
# Out:
# 2011-12-09

# %%
#create a new column called date which contains the date of invoice only
retail_uk['date'] = retail_uk['InvoiceDate'].dt.date
retail_uk.head()
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 19632    537879     22114    HOT WATER BOTTLE TEA AND SYMPATHY        12
# 19633    537879     22835      HOT WATER BOTTLE I AM SO POORLY         8
# 19634    537879     85150        LADIES & GENTLEMEN METAL SIGN         6
# 19635    537879     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS         4
# 19636    537879     21524       DOORMAT SPOTTY HOME SWEET HOME         2
#
#               InvoiceDate  UnitPrice  CustomerID         Country        date
# 19632 2010-12-09 08:34:00       3.95     14243.0  United Kingdom  2010-12-09
# 19633 2010-12-09 08:34:00       4.65     14243.0  United Kingdom  2010-12-09
# 19634 2010-12-09 08:34:00       2.55     14243.0  United Kingdom  2010-12-09
# 19635 2010-12-09 08:34:00       7.95     14243.0  United Kingdom  2010-12-09
# 19636 2010-12-09 08:34:00       7.95     14243.0  United Kingdom  2010-12-09

# %%
# group by customers and check last date of purshace
recency_df = retail_uk.groupby(by='CustomerID', as_index=False)['date'].max()
recency_df.columns = ['CustomerID','LastPurshaceDate']
recency_df.head()
# Out:
#    CustomerID LastPurshaceDate
# 0     12346.0       2011-01-18
# 1     12747.0       2011-12-07
# 2     12748.0       2011-12-09
# 3     12749.0       2011-12-06
# 4     12820.0       2011-12-06

# %%
#calculate recency
recency_df['Recency'] = recency_df['LastPurshaceDate'].apply(lambda x: (now - x).days)
recency_df.head()
# Out:
#    CustomerID LastPurshaceDate  Recency
# 0     12346.0       2011-01-18      325
# 1     12747.0       2011-12-07        2
# 2     12748.0       2011-12-09        0
# 3     12749.0       2011-12-06        3
# 4     12820.0       2011-12-06        3

# %%
#drop LastPurchaseDate as we don't need it anymore
recency_df.drop('LastPurshaceDate',axis=1,inplace=True)

# %% [markdown]
# Now we have the recency attribute created. e.g: Customer with ID = 12346 did his/her last purshace 325 days ago.

# %% [markdown]
# ### Frequency
# * Frequency helps us to know how many times a customer purchased from us. To do that we need to check how many invoices are registered by the same customer.

# %%
# drop duplicates
retail_uk_copy = retail_uk
retail_uk_copy.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], keep="first", inplace=True)
#calculate frequency of purchases
frequency_df = retail_uk_copy.groupby(by=['CustomerID'], as_index=False)['InvoiceNo'].count()
frequency_df.columns = ['CustomerID','Frequency']
frequency_df.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          1
# 1     12747.0         10
# 2     12748.0        196
# 3     12749.0          5
# 4     12820.0          4

# %% [markdown]
# ### Monetary
# * Monetary attribute answers the question: How much money did the customer spent over time?

# %%
#create column total cost
retail_uk['TotalCost'] = retail_uk['Quantity'] * retail_uk['UnitPrice']

# grouping by customer id
monetary_df = retail_uk.groupby(by='CustomerID',as_index=False).agg({'TotalCost': 'sum'})
monetary_df.columns = ['CustomerID','Monetary']
monetary_df.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0  77183.60
# 1     12747.0    658.89
# 2     12748.0   3739.23
# 3     12749.0     98.35
# 4     12820.0     58.20

# %% [markdown]
# ### Create RFM Table

# %%
#merge recency dataframe with frequency dataframe
temp_df = recency_df.merge(frequency_df,on='CustomerID')
temp_df.head()
# Out:
#    CustomerID  Recency  Frequency
# 0     12346.0      325          1
# 1     12747.0        2         10
# 2     12748.0        0        196
# 3     12749.0        3          5
# 4     12820.0        3          4

# %%
#merge with monetary dataframe to get a table with the 3 columns
rfm_df = temp_df.merge(monetary_df,on='CustomerID')

#use CustomerID as index
rfm_df.set_index('CustomerID',inplace=True)

#check the head
rfm_df.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          1  77183.60
# 12747.0           2         10    658.89
# 12748.0           0        196   3739.23
# 12749.0           3          5     98.35
# 12820.0           3          4     58.20

# %% [markdown]
# * Customer with ID = 12346 has recency: 325 days, frequency:1, and monetary: 77183.60 £.

# %% [markdown]
# ### RFM Table Correctness verification

# %%
retail_uk[retail_uk['CustomerID']==12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country        date  \
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom  2011-01-18
#
#        TotalCost
# 61619    77183.6

# %%
(now - dt.date(2011,1,18)).days == 325
# Out:
# True

# %% [markdown]
# * As we can see our RFM table is correct. The first customer bought only once, and only one product with huge amount.

# %% [markdown]
# ### Customer segments with RFM Model
# * Before moving to customer segments, Let's see the application of Pareto Principle – commonly referred to as the 80-20 rule on our dataset by applying it to our RFM variables.
#
# * Pareto’s rule says 80% of the results come from 20% of the causes.
#
# * Similarly, 20% customers contribute to 80% of your total revenue. Let's verify that because that will help us know which customers to focus on when marketing new products.

# %% [markdown]
# ### Applying 80-20 rule

# %%
#get the 80% of the revenue
pareto_cutoff = rfm_df['Monetary'].sum() * 0.8
print("The 80% of total revenue is: ",round(pareto_cutoff,2))
# Out:
# The 80% of total revenue is:  890679.54

# %%
customers_rank = rfm_df
# Create a new column that is the rank of the value of coverage in ascending order
customers_rank['Rank'] = customers_rank['Monetary'].rank(ascending=0)
#customers_rank.drop('RevenueRank',axis=1,inplace=True)
customers_rank.head()
# Out:
#             Recency  Frequency  Monetary    Rank
# CustomerID
# 12346.0         325          1  77183.60     2.0
# 12747.0           2         10    658.89   183.0
# 12748.0           0        196   3739.23    34.0
# 12749.0           3          5     98.35  1140.0
# 12820.0           3          4     58.20  1665.5

# %% [markdown]
# ### Top Customers

# %%
customers_rank.sort_values('Rank',ascending=True)
# Out:
#             Recency  Frequency   Monetary    Rank
# CustomerID
# 16446.0           0          2  168471.25     1.0
# 12346.0         325          1   77183.60     2.0
# 15098.0         182          3   39916.50     3.0
# 18102.0           0         57   39646.45     4.0
# 17949.0           1         44   28685.69     5.0
# ...             ...        ...        ...     ...
# 15503.0         362          1       0.42  3859.5
# 15645.0          18          1       0.42  3859.5
# 17914.0           3          1       0.39  3861.5
# 13271.0          37          1       0.39  3861.5
# 13256.0          14          1       0.00  3863.0
#
# [3863 rows x 4 columns]

# %%
# get top 20% of the customers
top_20_cutoff = 3863 *20 /100
top_20_cutoff
# Out:
# 772.6

# %%
#sum the monetary values over the customer with rank <=773
revenueByTop20 = customers_rank[customers_rank['Rank'] <= 772]['Monetary'].sum()
revenueByTop20
# Out:
# 976683.3499999999

# %% [markdown]
# The 80% of total revenue is not achieved by the 20% of TOP customers but approximately, it does, because they are less than our 20% TOP customers who achieve it.

# %% [markdown]
# ### Applying RFM score formula
# * The simplest way to create customers segments from RFM Model is to use Quartiles. We assign a score from 1 to 4 to Recency, Frequency and Monetary. Four is the best/highest value, and one is the lowest/worst value.
# * A final RFM score is calculated simply by combining individual RFM score numbers.

# %%
# RFM Quartiles
quantiles = rfm_df.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       Recency  Frequency  Monetary    Rank
# 0.25     17.0        1.0      17.4   966.5
# 0.50     49.0        2.0      45.0  1930.5
# 0.75    134.0        5.0     121.6  2898.0

# %% [markdown]
# ### Creation of RFM segmentation table
# * We will create two segmentation classes since, high recency is bad, while high frequency and monetary value is good.

# %%
quantiles.to_dict()
# Arguments (x = value, p = recency, monetary_value, frequency, d = quartiles dict)
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4

# %%
#create rfm segmentation table
rfm_segmentation = rfm_df
rfm_segmentation['R_Quartile'] = rfm_segmentation['Recency'].apply(RScore, args=('Recency',quantiles,))
rfm_segmentation['F_Quartile'] = rfm_segmentation['Frequency'].apply(FMScore, args=('Frequency',quantiles,))
rfm_segmentation['M_Quartile'] = rfm_segmentation['Monetary'].apply(FMScore, args=('Monetary',quantiles,))
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary    Rank  R_Quartile  F_Quartile  \
# CustomerID
# 12346.0         325          1  77183.60     2.0           1           1
# 12747.0           2         10    658.89   183.0           4           4
# 12748.0           0        196   3739.23    34.0           4           4
# 12749.0           3          5     98.35  1140.0           4           3
# 12820.0           3          4     58.20  1665.5           4           3
#
#             M_Quartile
# CustomerID
# 12346.0              4
# 12747.0              4
# 12748.0              4
# 12749.0              3
# 12820.0              3

# %% [markdown]
# * Now that we have the score of each customer, we can represent our customer segmentation.
# * First, we need to combine the scores (R_Quartile, F_Quartile,M_Quartile) together.

# %%
rfm_segmentation['RFMScore'] = rfm_segmentation.R_Quartile.map(str) \
                            + rfm_segmentation.F_Quartile.map(str) \
                            + rfm_segmentation.M_Quartile.map(str)
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary    Rank  R_Quartile  F_Quartile  \
# CustomerID
# 12346.0         325          1  77183.60     2.0           1           1
# 12747.0           2         10    658.89   183.0           4           4
# 12748.0           0        196   3739.23    34.0           4           4
# 12749.0           3          5     98.35  1140.0           4           3
# 12820.0           3          4     58.20  1665.5           4           3
#
#             M_Quartile RFMScore
# CustomerID
# 12346.0              4      114
# 12747.0              4      444
# 12748.0              4      444
# 12749.0              3      433
# 12820.0              3      433

# %% [markdown]
# * Best Recency score = 4: most recently purchase. Best Frequency score = 4: most quantity purchase. Best Monetary score = 4: spent the most.
#
# * Let's see who are our Champions (best customers).

# %%
rfm_segmentation[rfm_segmentation['RFMScore']=='444'].sort_values('Monetary', ascending=False).head(10)
# Out:
#             Recency  Frequency  Monetary  Rank  R_Quartile  F_Quartile  \
# CustomerID
# 18102.0           0         57  39646.45   4.0           4           4
# 17949.0           1         44  28685.69   5.0           4           4
# 17450.0           8         44  25953.51   6.0           4           4
# 16013.0           3         45  17163.28   8.0           4           4
# 16333.0           7         22  14418.96   9.0           4           4
# 15769.0           7         25  11660.84  11.0           4           4
# 12901.0           8         28   9230.45  12.0           4           4
# 13798.0           1         56   7786.26  13.0           4           4
# 16684.0           4         28   7700.08  14.0           4           4
# 17857.0           4         23   7655.18  15.0           4           4
#
#             M_Quartile RFMScore
# CustomerID
# 18102.0              4      444
# 17949.0              4      444
# 17450.0              4      444
# ...

# %% [markdown]
# ### How many customers do we have in each segment?

# %%
# How many customers do we have in each segment?

print("Best Customers: ",len(rfm_segmentation[rfm_segmentation['RFMScore']=='444']))
print('Loyal Customers: ',len(rfm_segmentation[rfm_segmentation['F_Quartile']==4]))
print("Big Spenders: ",len(rfm_segmentation[rfm_segmentation['M_Quartile']==4]))
print('Almost Lost: ', len(rfm_segmentation[rfm_segmentation['RFMScore']=='244']))
print('Lost Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='144']))
print('Lost Cheap Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='111']))
# Out:
# Best Customers:  356
# Loyal Customers:  752
# Big Spenders:  966
# Almost Lost:  64
# Lost Customers:  9
# Lost Cheap Customers:  353

# %% [markdown]
# ## **Applying K-means clustering on RFM variables**
# ### Preprocessing the Data

# %%
rfm_data = rfm_df.drop(['R_Quartile','F_Quartile','M_Quartile','RFMScore'],axis=1)
rfm_data.head()
# Out:
#             Recency  Frequency  Monetary    Rank
# CustomerID
# 12346.0         325          1  77183.60     2.0
# 12747.0           2         10    658.89   183.0
# 12748.0           0        196   3739.23    34.0
# 12749.0           3          5     98.35  1140.0
# 12820.0           3          4     58.20  1665.5

# %%
# Feature correlations
rfm_data.corr()
# Out:
#             Recency  Frequency  Monetary      Rank
# Recency    1.000000  -0.279236 -0.027727  0.323091
# Frequency -0.279236   1.000000  0.156431 -0.458849
# Monetary  -0.027727   0.156431  1.000000 -0.130520
# Rank       0.323091  -0.458849 -0.130520  1.000000

# %%
sns.heatmap(rfm_data.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### Visualize feature distributions
# * To get a better understanding of the dataset, we can construct a scatter matrix of each of the three features present in the RFM data.

# %%
# Produce a scatter matrix for each pair of features in the data
scatter_matrix(rfm_data, alpha = 0.3, figsize = (11,5), diagonal = 'kde');

# %% [markdown]
# * We can notice that we have a skewed distribution of the 3 variables and there exist outliers.
#
# * This indicates how normalization is required to make the data features normally distributed as clustering algorithms require them to be normally distributed.

# %% [markdown]
# ### Data Normalization

# %%
#log transformation
rfm_r_log = np.log(rfm_data['Recency']+0.1) #can't take log(0) and so add a small number
rfm_f_log = np.log(rfm_data['Frequency'])
rfm_m_log = np.log(rfm_data['Monetary']+0.1)
log_data = pd.DataFrame({'Monetary': rfm_m_log,'Recency': rfm_r_log,'Frequency': rfm_f_log})
log_data.head()
# Out:
#              Monetary   Recency  Frequency
# CustomerID
# 12346.0     11.253944  5.784133   0.000000
# 12747.0      6.490708  0.741937   2.302585
# 12748.0      8.226662 -2.302585   5.278115
# 12749.0      4.589549  1.131402   1.609438
# 12820.0      4.065602  1.131402   1.386294

# %%
# Produce a scatter matrix for each pair of features in the data
scatter_matrix(log_data, alpha = 0.2, figsize = (11,5), diagonal = 'kde');

# %% [markdown]
# The distributions of Frequency and Monetary are better, more normalized, but it's not the case with Recency Distribution, which is improved but not as much.

# %%
# heatmap of rfm data
sns.heatmap(rfm_data.corr())
# Out:
# <Axes: >

# %%
# heatmap of log_data
sns.heatmap(log_data.corr())
# Out:
# <Axes: >

# %%
# corelation of log_data
log_data.corr()
# Out:
#            Monetary   Recency  Frequency
# Monetary   1.000000 -0.364351   0.715609
# Recency   -0.364351  1.000000  -0.569951
# Frequency  0.715609 -0.569951   1.000000

# %% [markdown]
# * Now, Monetary and Frequency are more strongly correlated.

# %% [markdown]
# ## **K-means Implementation**

# %% [markdown]
# * A common challenge with k-means is that you must tell it how many clusters you expect. Figuring out how many clusters we need is not obvious from data, thus we will try different clusters numbers and check their silhouette coefficient.
# * The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# * The elbow method can be used to determine the number of clusters as well.

# %%
matrix = log_data.to_numpy()
for n_clusters in range(2,10):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=100)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.38940554101987457
# For n_clusters = 3 The average silhouette_score is : 0.3036071052941144
# For n_clusters = 4 The average silhouette_score is : 0.3097934824953256
# For n_clusters = 5 The average silhouette_score is : 0.28983218417169326
# For n_clusters = 6 The average silhouette_score is : 0.29504470211239786
# For n_clusters = 7 The average silhouette_score is : 0.29128648080510633
# For n_clusters = 8 The average silhouette_score is : 0.29202098589678444
# For n_clusters = 9 The average silhouette_score is : 0.2946976693888283

# %% [markdown]
# The best silhouette score obtained is when the number of clusters is 2.

# %%
n_clusters = 2
kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=30)
kmeans.fit(matrix)
clusters_customers = kmeans.predict(matrix)
silhouette_avg = silhouette_score(matrix, clusters_customers)
round(silhouette_avg,2)
# Out:
# 0.39

# %% [markdown]
# ### Visualize Clusters

# %%
#create a scatter plot
plt.scatter(matrix[:, 0], matrix[:, 1], c=clusters_customers, s=50, cmap='viridis')
#select cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
# What's the number of customers in each cluster?
pd.DataFrame(pd.Series(clusters_customers).value_counts(), columns = ['NumberCustomers']).T
# Out:
#                     0     1
# NumberCustomers  2337  1526

# %% [markdown]
# ## **Correlation Heatmap**

# %%
sns.heatmap(retail_uk.corr())
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Shows relations of varialbles

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Quantity is positively corelated to total cost

# %% [markdown]
# ## **Pair Plot**

# %%
# Pair Plot visualization code
sns.pairplot(retail_uk)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It gives glance of variable relation in the form of small chart in a single view.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Starting with loading the dataset then preprocessing and modelling the follwing conclusion can be drawn-
# * From RFM Model
# 1. Top 20% of the customers ranks upto 713.
# 2. The 80% of total revenue is:  890679.54 which is come from top 20 % of customers.
# 3. These top 20 % customers are more active customers in term of recency, frequency and monetary value.
# 4. Result of segmentation is:
# Best Customers:  356
#  * Loyal Customers:  752
#  * Big Spenders:  966
#  * Almost Lost:  64
#  * Lost Customers:  9
#  * Lost Cheap Customers:  353
# * From kmeans model-
# 1. The best silhouette score obtained is when the number of clusters is 2.
# 2. silhouette score is 3.9

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
